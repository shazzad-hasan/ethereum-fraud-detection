# %% [markdown]
# <a href="https://colab.research.google.com/github/shazzad-hasan/ethereum-fraud-detection/blob/main/data-preparation/kaggle_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_k = pd.read_csv('/content/drive/MyDrive/ethereum-fraud-detection/data/address_data_k.csv')

# %%
df_k.drop(['Unnamed: 0', 'Index'], axis=1, inplace=True)
df_k.drop_duplicates(subset=["Address"], inplace=True)

# %%
df_k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9816 entries, 0 to 9840
# Data columns (total 49 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Address                                               9816 non-null   object
#  1   FLAG                                                  9816 non-null   int64
#  2   Avg min between sent tnx                              9816 non-null   float64
#  3   Avg min between received tnx                          9816 non-null   float64
#  4   Time Diff between first and last (Mins)               9816 non-null   float64
#  5   Sent tnx                                              9816 non-null   int64
#  6   Received Tnx                                          9816 non-null   int64
#  7   Number of Created Contracts                           9816 non-null   int64
#  8   Unique Received From Addresses                        9816 non-null   int64
#  9   Unique Sent To Addresses                              9816 non-null   int64
#  10  min value received                                    9816 non-null   float64
#  11  max value received                                    9816 non-null   float64
#  12  avg val received                                      9816 non-null   float64
#  13  min val sent                                          9816 non-null   float64
#  14  max val sent                                          9816 non-null   float64
#  15  avg val sent                                          9816 non-null   float64
#  16  min value sent to contract                            9816 non-null   float64
#  17  max val sent to contract                              9816 non-null   float64
#  18  avg value sent to contract                            9816 non-null   float64
#  19  total transactions (including tnx to create contract  9816 non-null   int64
#  20  total Ether sent                                      9816 non-null   float64
#  21  total ether received                                  9816 non-null   float64
#  22  total ether sent contracts                            9816 non-null   float64
#  23  total ether balance                                   9816 non-null   float64
#  24   Total ERC20 tnxs                                     8987 non-null   float64
#  25   ERC20 total Ether received                           8987 non-null   float64
#  26   ERC20 total ether sent                               8987 non-null   float64
#  27   ERC20 total Ether sent contract                      8987 non-null   float64
#  28   ERC20 uniq sent addr                                 8987 non-null   float64
#  29   ERC20 uniq rec addr                                  8987 non-null   float64
#  30   ERC20 uniq sent addr.1                               8987 non-null   float64
#  31   ERC20 uniq rec contract addr                         8987 non-null   float64
#  32   ERC20 avg time between sent tnx                      8987 non-null   float64
#  33   ERC20 avg time between rec tnx                       8987 non-null   float64
#  34   ERC20 avg time between rec 2 tnx                     8987 non-null   float64
#  35   ERC20 avg time between contract tnx                  8987 non-null   float64
#  36   ERC20 min val rec                                    8987 non-null   float64
#  37   ERC20 max val rec                                    8987 non-null   float64
#  38   ERC20 avg val rec                                    8987 non-null   float64
#  39   ERC20 min val sent                                   8987 non-null   float64
#  40   ERC20 max val sent                                   8987 non-null   float64
#  41   ERC20 avg val sent                                   8987 non-null   float64
#  42   ERC20 min val sent contract                          8987 non-null   float64
#  43   ERC20 max val sent contract                          8987 non-null   float64
#  44   ERC20 avg val sent contract                          8987 non-null   float64
#  45   ERC20 uniq sent token name                           8987 non-null   float64
#  46   ERC20 uniq rec token name                            8987 non-null   float64
#  47   ERC20 most sent token type                           7127 non-null   object
#  48   ERC20_most_rec_token_type                            8945 non-null   object
# dtypes: float64(39), int64(7), object(3)
# memory usage: 3.7+ MB

# %%
df_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4339 entries, 0 to 4338
# Data columns (total 24 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Address                                               4339 non-null   object
#  1   FLAG                                                  4339 non-null   int64
#  2   Avg min between sent tnx                              4339 non-null   float64
#  3   Avg min between received tnx                          4339 non-null   float64
#  4   Time Diff between first and last (Mins)               4339 non-null   float64
#  5   Sent tnx                                              4339 non-null   int64
#  6   Received Tnx                                          4339 non-null   int64
#  7   Number of Created Contracts                           4339 non-null   int64
#  8   Unique Received From Addresses                        4339 non-null   int64
#  9   Unique Sent To Addresses                              4339 non-null   int64
#  10  min value received                                    4339 non-null   float64
#  11  max value received                                    4339 non-null   float64
#  12  avg val received                                      4339 non-null   float64
#  13  min val sent                                          4339 non-null   float64
#  14  max val sent                                          4339 non-null   float64
#  15  avg val sent                                          4339 non-null   float64
#  16  min value sent to contract                            1495 non-null   float64
#  17  max val sent to contract                              1495 non-null   float64
#  18  avg value sent to contract                            1495 non-null   float64
#  19  total transactions (including tnx to create contract  4339 non-null   int64
#  20  total Ether sent                                      4339 non-null   float64
#  21  total ether received                                  4339 non-null   float64
#  22  total ether sent contracts                            4339 non-null   float64
#  23  total ether balance                                   4339 non-null   float64
# dtypes: float64(16), int64(7), object(1)
# memory usage: 813.7+ KB

# %%
categories = df_k.select_dtypes('O').columns.astype('category')
for catg in df_k[categories].columns:
    print(f'The categorical column {catg} has {len(df_k[catg].value_counts())} unique values')
# Out:
# The categorical column Address has 9816 unique values
# The categorical column  ERC20 most sent token type has 304 unique values
# The categorical column  ERC20_most_rec_token_type has 466 unique values

# %%
numericals = df_k.select_dtypes(include=['float','int']).columns
for num in df_k[numericals].columns:
    print(f'The categorical column {num} has {len(df_k[num].value_counts())} unique values')
# Out:
# The categorical column FLAG has 2 unique values
# The categorical column Avg min between sent tnx has 5013 unique values
# The categorical column Avg min between received tnx has 6223 unique values
# The categorical column Time Diff between first and last (Mins) has 7810 unique values
# The categorical column Sent tnx has 641 unique values
# The categorical column Received Tnx has 727 unique values
# The categorical column Number of Created Contracts has 20 unique values
# The categorical column Unique Received From Addresses has 256 unique values
# The categorical column Unique Sent To Addresses has 258 unique values
# The categorical column min value received has 4589 unique values
# The categorical column max value received  has 6302 unique values
# The categorical column avg val received has 6767 unique values
# The categorical column min val sent has 4719 unique values
# The categorical column max val sent has 6647 unique values
# The categorical column avg val sent has 5854 unique values
# The categorical column min value sent to contract has 3 unique values
# The categorical column max val sent to contract has 4 unique values
# The categorical column avg value sent to contract has 4 unique values
# The categorical column total transactions (including tnx to create contract has 897 unique values
# The categorical column total Ether sent has 5868 unique values
# The categorical column total ether received has 6728 unique values
# The categorical column total ether sent contracts has 4 unique values
# The categorical column total ether balance has 5717 unique values
# The categorical column  Total ERC20 tnxs has 300 unique values
# The categorical column  ERC20 total Ether received has 3460 unique values
# The categorical column  ERC20 total ether sent has 1415 unique values
# The categorical column  ERC20 total Ether sent contract has 29 unique values
# The categorical column  ERC20 uniq sent addr has 107 unique values
# The categorical column  ERC20 uniq rec addr has 147 unique values
# The categorical column  ERC20 uniq sent addr.1 has 4 unique values
# The categorical column  ERC20 uniq rec contract addr has 123 unique values
# The categorical column  ERC20 avg time between sent tnx has 1 unique values
# The categorical column  ERC20 avg time between rec tnx has 1 unique values
# The categorical column  ERC20 avg time between rec 2 tnx has 1 unique values
# The categorical column  ERC20 avg time between contract tnx has 1 unique values
# The categorical column  ERC20 min val rec has 1276 unique values
# The categorical column  ERC20 max val rec has 2647 unique values
# The categorical column  ERC20 avg val rec has 3380 unique values
# The categorical column  ERC20 min val sent has 476 unique values
# The categorical column  ERC20 max val sent has 1130 unique values
# The categorical column  ERC20 avg val sent has 1309 unique values
# The categorical column  ERC20 min val sent contract has 1 unique values
# The categorical column  ERC20 max val sent contract has 1 unique values
# The categorical column  ERC20 avg val sent contract has 1 unique values
# The categorical column  ERC20 uniq sent token name has 70 unique values
# The categorical column  ERC20 uniq rec token name has 121 unique values

# %%
# Feature variances
df_k[numericals].var()
# Out:
# FLAG                                                    1.727250e-01
# Avg min between sent tnx                                4.616454e+08
# Avg min between received tnx                            5.324319e+08
# Time Diff between first and last (Mins)                 1.042427e+11
# Sent tnx                                                5.747996e+05
# Received Tnx                                            8.873719e+05
# Number of Created Contracts                             2.005778e+04
# Unique Received From Addresses                          8.939983e+04
# Unique Sent To Addresses                                6.977606e+04
# min value received                                      1.064405e+05
# max value received                                      1.696598e+08
# avg val received                                        8.344257e+06
# min val sent                                            1.926153e+04
# max val sent                                            4.405729e+07
# avg val sent                                            5.721059e+04
# min value sent to contract                              5.093309e-08
# max val sent to contract                                2.667427e-07
# avg value sent to contract                              1.048760e-07
# total transactions (including tnx to create contract    1.833474e+06
# total Ether sent                                        1.287220e+11
# total ether received                                    1.329827e+11
# total ether sent contracts                              2.667400e-07
# total ether balance                                     5.891977e+10
#  Total ERC20 tnxs                                       2.008286e+05
#  ERC20 total Ether received                             1.113707e+20
#  ERC20 total ether sent                                 1.397196e+18
#  ERC20 total Ether sent contract                        3.766463e+07
#  ERC20 uniq sent addr                                   1.110881e+04
#  ERC20 uniq rec addr                                    6.712373e+03
#  ERC20 uniq sent addr.1                                 4.328185e-03
#  ERC20 uniq rec contract addr                           2.973756e+02
#  ERC20 avg time between sent tnx                        0.000000e+00
#  ERC20 avg time between rec tnx                         0.000000e+00
#  ERC20 avg time between rec 2 tnx                       0.000000e+00
#  ERC20 avg time between contract tnx                    0.000000e+00
#  ERC20 min val rec                                      2.858375e+08
#  ERC20 max val rec                                      1.113458e+20
#  ERC20 avg val rec                                      4.597455e+16
#  ERC20 min val sent                                     1.113091e+12
#  ERC20 max val sent                                     1.396049e+18
#  ERC20 avg val sent                                     3.508175e+17
#  ERC20 min val sent contract                            0.000000e+00
#  ERC20 max val sent contract                            0.000000e+00
#  ERC20 avg val sent contract                            0.000000e+00
#  ERC20 uniq sent token name                             4.519851e+01
#  ERC20 uniq rec token name                              2.780912e+02
# dtype: float64

# %%
# Visualize missing values
plt.figure(figsize=(14,8))
sns.heatmap(df_k.isnull(), cbar=False)
plt.show()

# %%
# Drop Categorical Features
df_k.drop(list(categories), axis=1, inplace=True)

# Replace missing values with mean
df_k.fillna(df_k.median(), inplace=True)

# Drop features with 0 variance
zero_var_features = df_k.var() == 0
df_k.drop(df_k.var()[zero_var_features].index, axis=1, inplace=True)

# %%
# Visualize missing values
plt.figure(figsize=(14,8))
sns.heatmap(df_k.isnull(), cbar=False)
plt.show()

# %%
feature_list = list(set(df_k.columns) - set(['Address']))

corr_matrix = df_k[list(set(feature_list))].corr().round(2)
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)]=True
plt.figure(figsize=(25, 20))
sns.heatmap(data=corr_matrix, mask=mask, square=True, annot=True, cmap="crest", center=0, linewidth=.5)
plt.show()

# %%
corr_threshold = 0.7
boolean_mask = mask.astype(bool)
red_corr_matrix = corr_matrix.mask(boolean_mask)
corr_matrix_unstacked = red_corr_matrix.unstack()
similar_features = corr_matrix_unstacked[abs(corr_matrix_unstacked) >= corr_threshold].reset_index().rename(columns={'level_0': 'feature_1', 'level_1': 'feature_2', 0: 'Absolute Correlation'})
similar_features.sort_values(by="Absolute Correlation",ascending=False)
# Out:
#                                             feature_1  \
# 10                       ERC20 uniq rec contract addr
# 15                             ERC20 total ether sent
# 19                         ERC20 total Ether received
# 3                                  ERC20 max val sent
# 4                                  ERC20 max val sent
# 5                                  ERC20 max val sent
# 6                                  ERC20 min val sent
# 7                                  ERC20 min val sent
# 18                           max val sent to contract
# 17                         avg value sent to contract
# 16                         avg value sent to contract
# 11                                  ERC20 avg val rec
# 12                                  ERC20 avg val rec
# 0   total transactions (including tnx to create co...
# 9                        ERC20 uniq rec contract addr
# 20                         ERC20 uniq sent token name
# 8                                    total Ether sent
# 14                                   Total ERC20 tnxs
# 1   total transactions (including tnx to create co...
# 13                                ERC20 uniq rec addr
# 2                          min value sent to contract
#
#                       feature_2  Absolute Correlation
# 10    ERC20 uniq rec token name                  1.00
# 15           ERC20 avg val sent                  1.00
# 19            ERC20 max val rec                  1.00
# 3            ERC20 min val sent                  1.00
# 4        ERC20 total ether sent                  1.00
# 5            ERC20 avg val sent                  1.00
# 6        ERC20 total ether sent                  1.00
# 7            ERC20 avg val sent                  1.00
# 18   total ether sent contracts                  1.00
# 17   total ether sent contracts                  0.95
# 16     max val sent to contract                  0.95
# 11   ERC20 total Ether received                  0.86
# 12            ERC20 max val rec                  0.86
# 0                  Received Tnx                  0.81
# 9    ERC20 uniq sent token name                  0.79
# 20    ERC20 uniq rec token name                  0.79
# 8          total ether received                  0.77
# 14         ERC20 uniq sent addr                  0.73
# 1                      Sent tnx                  0.73
# 13             Total ERC20 tnxs                  0.72
# 2    avg value sent to contract                  0.70

# %%
df_k.columns
# Out:
# Index(['FLAG', 'Avg min between sent tnx', 'Avg min between received tnx',
#        'Time Diff between first and last (Mins)', 'Sent tnx', 'Received Tnx',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'Unique Sent To Addresses', 'min value received', 'max value received ',
#        'avg val received', 'min val sent', 'max val sent', 'avg val sent',
#        'min value sent to contract', 'max val sent to contract',
#        'avg value sent to contract',
#        'total transactions (including tnx to create contract',
#        'total Ether sent', 'total ether received',
#        'total ether sent contracts', 'total ether balance',
#        ' Total ERC20 tnxs', ' ERC20 total Ether received',
#        ' ERC20 total ether sent', ' ERC20 total Ether sent contract',
#        ' ERC20 uniq sent addr', ' ERC20 uniq rec addr',
#        ' ERC20 uniq sent addr.1', ' ERC20 uniq rec contract addr',
#        ' ERC20 min val rec', ' ERC20 max val rec', ' ERC20 avg val rec',
#        ' ERC20 min val sent', ' ERC20 max val sent', ' ERC20 avg val sent',
#        ' ERC20 uniq sent token name', ' ERC20 uniq rec token name'],
#       dtype='object')

# %%
high_corr_feature_list = ['ERC20 uniq rec token name','ERC20 uniq rec contract addr','max val sent to contract',
                         'total ether sent contracts', 'ERC20 avg val sent', 'ERC20 min val sent',
                         'ERC20 max val sent', 'ERC20 total ether sent', 'ERC20 total Ether received',
                         'ERC20 max val rec', 'avg value sent to contract', 'ERC20 avg val rec',
                         'total transactions (including tnx to create contract', 'Received Tnx', 'ERC20 uniq sent token name',
                         'total ether received', 'total Ether sent', 'Total ERC20 tnxs',
                         'ERC20 uniq sent addr', 'Sent tnx', 'ERC20 uniq rec addr', 'min value sent to contract']

df_k.columns = df_k.columns.str.strip()
df_k.drop(high_corr_feature_list, axis=1, inplace=True)

# %%
df_k.columns
# Out:
# Index(['FLAG', 'Avg min between sent tnx', 'Avg min between received tnx',
#        'Time Diff between first and last (Mins)',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'Unique Sent To Addresses', 'min value received', 'max value received',
#        'avg val received', 'min val sent', 'max val sent', 'avg val sent',
#        'total ether balance', 'ERC20 total Ether sent contract',
#        'ERC20 uniq sent addr.1', 'ERC20 min val rec'],
#       dtype='object')

# %%
feature_list = list(set(df_k.columns))
corr_matrix = df_k[list(set(feature_list))].corr().round(2)
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)]=True
plt.figure(figsize=(15, 10))
sns.heatmap(data=corr_matrix, mask=mask, square=True, annot=True, cmap="crest", center=0, linewidth=.5)
plt.show()

# %%
# Distribution of features
columns = df_k.columns

fig, axes = plt.subplots(5, 3, figsize=(12,10), constrained_layout =True)

ax = sns.boxplot(ax = axes[0,0], data=df_k, x=columns[1])
ax.set_title(f'{columns[1]}')

ax1 = sns.boxplot(ax = axes[0,1], data=df_k, x=columns[2])
ax1.set_title(f'{columns[2]}')

ax2 = sns.boxplot(ax = axes[0,2], data=df_k, x=columns[3])
ax2.set_title(f'{columns[3]}')

ax3 = sns.boxplot(ax = axes[1,0], data=df_k, x=columns[4])
ax3.set_title(f'{columns[4]}')

ax4 = sns.boxplot(ax = axes[1,1], data=df_k, x=columns[5])
ax4.set_title(f'{columns[5]}')

ax5 = sns.boxplot(ax = axes[1,2], data=df_k, x=columns[6])
ax5.set_title(f'{columns[6]}')

ax6 = sns.boxplot(ax = axes[2,0], data=df_k, x=columns[7])
ax6.set_title(f'{columns[7]}')

ax7 = sns.boxplot(ax = axes[2,1], data=df_k, x=columns[8])
ax7.set_title(f'{columns[8]}')

ax8 = sns.boxplot(ax = axes[2,2], data=df_k, x=columns[9])
ax8.set_title(f'{columns[9]}')

ax9 = sns.boxplot(ax = axes[3,0], data=df_k, x=columns[10])
ax9.set_title(f'{columns[10]}')

ax10 = sns.boxplot(ax = axes[3,1], data=df_k, x=columns[11])
ax10.set_title(f'{columns[11]}')

ax11 = sns.boxplot(ax = axes[3,2], data=df_k, x=columns[12])
ax11.set_title(f'{columns[12]}')

ax12 = sns.boxplot(ax = axes[4,0], data=df_k, x=columns[13])
ax12.set_title(f'{columns[13]}')

ax13 = sns.boxplot(ax = axes[4,1], data=df_k, x=columns[14])
ax13.set_title(f'{columns[14]}')

ax14 = sns.boxplot(ax = axes[4,2], data=df_k, x=columns[15])
ax14.set_title(f'{columns[15]}')

plt.show()

# %%
# Some features present a small distribution
for i in df_k.columns[1:]:
    if len(df_k[i].value_counts()) < 10:
        print(f"Feature '{i}' has the following distribution: \n{df_k[i].value_counts()}")
# Out:
# Feature 'ERC20 uniq sent addr.1' has the following distribution:
# ERC20 uniq sent addr.1
# 0.0    9788
# 1.0      26
# 3.0       1
# 2.0       1
# Name: count, dtype: int64

# %%
df_k.drop(['ERC20 uniq sent addr.1'], axis=1, inplace=True)

# %%
df_k.columns
# Out:
# Index(['FLAG', 'Avg min between sent tnx', 'Avg min between received tnx',
#        'Time Diff between first and last (Mins)',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'Unique Sent To Addresses', 'min value received', 'max value received',
#        'avg val received', 'min val sent', 'max val sent', 'avg val sent',
#        'total ether balance', 'ERC20 total Ether sent contract',
#        'ERC20 min val rec'],
#       dtype='object')

# %%
print(df_k['FLAG'].value_counts())

# Target Distribution
labels = ['Non-fraud', 'Fraud']

fig, ax = plt.subplots(1, 2, figsize=[10,5])
ax[0].pie(x=df_k['FLAG'].value_counts(), labels=labels)

sns.countplot(data=df_k, x='FLAG', hue='FLAG', palette=['#1f77b4', '#ff7f0e'], dodge=False)
plt.show()
# Out:
# FLAG
# 0    7637
# 1    2179
# Name: count, dtype: int64
