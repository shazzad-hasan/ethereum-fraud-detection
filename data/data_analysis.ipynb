# %% [markdown]
# <a href="https://colab.research.google.com/github/shazzad-hasan/ethereum-fraud-detection/blob/main/data/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ethereum-fraud-detection/data/address_data_combined_ts.csv')
df.head()
# Out:
#    Index                                     Address  FLAG  \
# 0      1  0x87d884aaa6ff9e9b6014631b0abae80b53953fb8     1
# 1      2  0xd42393df90d582bd8a5493171f0173e3a017d391     1
# 2      3  0x3025c36d8a9620d3df89e9e9b1acbdfd639a6f37     1
# 3      4  0x6309f709faad518fc158af4c14edfa7b06424770     1
# 4      5  0x3d020954e30c3d40b7f0c533cf198bc10dd45a49     1
#
#    Avg min between sent tnx  Avg min between received tnx  \
# 0                   5151.68                      15159.08
# 1                   1179.02                       1124.89
# 2                    361.73                          0.00
# 3                      0.00                          0.00
# 4                  14280.60                       1479.86
#
#    Time Diff between first and last (Mins)  Unique Received From Addresses  \
# 0                                 71235.62                               1
# 1                                 25126.45                              13
# 2                                   723.47                               1
# 3                                     0.00                               0
# 4                                 45357.57                              21
#
#    min value received  max value received   avg val received  ...  \
# 0            0.010000             0.020000          0.013367  ...
# 1            0.000000             0.750000          0.176667  ...
# 2            4.999916             4.999916          4.999916  ...
# 3            0.000000             0.000000          0.000000  ...
# 4            0.035000             0.200000          0.099286  ...
#
#    adjusted_eth_value__absolute_sum_of_changes  \
# 0                                     0.129900
# 1                                     7.669778
# 2                                     7.508992
# 3                                     0.000000
# 4                                     3.404658
#
#    adjusted_eth_value__mean_abs_change  \
# 0                             0.008119
# 1                             0.365228
# 2                             3.754496
# 3                             0.000000
# 4                             0.162127
#
#    adjusted_eth_value__energy_ratio_by_chunks__num_segments_10__segment_focus_0  \
# 0                                           0.358576
# 1                                           0.020237
# 2                                           0.666738
# 3                                           0.000000
# 4                                           0.006660
#
#    adjusted_eth_value__sum_values  adjusted_eth_value__abs_energy  \
# 0                        0.032100                        0.001400
# 1                       -0.284889                        3.335466
# 2                        0.000840                       37.494722
# 3                        0.000000                        0.000000
# 4                        0.000342                        4.594823
#
#    adjusted_eth_value__ratio_value_number_to_time_series_length  \
# 0                                           0.470588
# 1                                           0.409091
# 2                                           1.000000
# 3                                           0.000000
# 4                                           0.409091
#
#    adjusted_eth_value__quantile__q_0.1  adjusted_eth_value__count_below__t_0  \
# 0                             0.000000                              0.647059
# 1                            -0.267421                              0.363636
# 2                            -2.505261                              0.666667
# 3                             0.000000                              0.000000
# 4                             0.050000                              0.045455
#
#    adjusted_eth_value__count_above__t_0  adjusted_eth_value__median
# 0                              0.941176                       0.000
# 1                              0.681818                       0.150
# 2                              0.333333                      -2.490
# 3                              0.000000                       0.000
# 4                              0.954545                       0.085
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (13920, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13920 entries, 0 to 13919
# Data columns (total 25 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Index                                                                         13920 non-null  int64
#  1   Address                                                                       13920 non-null  object
#  2   FLAG                                                                          13920 non-null  int64
#  3   Avg min between sent tnx                                                      13920 non-null  float64
#  4   Avg min between received tnx                                                  13920 non-null  float64
#  5   Time Diff between first and last (Mins)                                       13920 non-null  float64
#  6   Unique Received From Addresses                                                13920 non-null  int64
#  7   min value received                                                            13920 non-null  float64
#  8   max value received                                                            13920 non-null  float64
#  9   avg val received                                                              13920 non-null  float64
#  10  min val sent                                                                  13920 non-null  float64
#  11  avg val sent                                                                  13920 non-null  float64
#  12  total transactions (including tnx to create contract                          13920 non-null  int64
#  13  total ether received                                                          13920 non-null  float64
#  14  total ether balance                                                           13920 non-null  float64
#  15  adjusted_eth_value__absolute_sum_of_changes                                   13920 non-null  float64
#  16  adjusted_eth_value__mean_abs_change                                           13920 non-null  float64
#  17  adjusted_eth_value__energy_ratio_by_chunks__num_segments_10__segment_focus_0  13920 non-null  float64
#  18  adjusted_eth_value__sum_values                                                13920 non-null  float64
#  19  adjusted_eth_value__abs_energy                                                13920 non-null  float64
#  20  adjusted_eth_value__ratio_value_number_to_time_series_length                  13920 non-null  float64
#  21  adjusted_eth_value__quantile__q_0.1                                           13920 non-null  float64
#  22  adjusted_eth_value__count_below__t_0                                          13920 non-null  float64
#  23  adjusted_eth_value__count_above__t_0                                          13920 non-null  float64
#  24  adjusted_eth_value__median                                                    13920 non-null  float64
# dtypes: float64(20), int64(4), object(1)
# memory usage: 2.7+ MB

# %%
feature_list = list(set(df.columns) - set(['Address', 'Index', 'FLAG']))

corr = df[list(set(feature_list))].corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
plt.figure(figsize=(20, 20))
sns.heatmap(data=corr, mask=mask, square=True, annot=True, cmap='CMRmap', center=0)
plt.show()
